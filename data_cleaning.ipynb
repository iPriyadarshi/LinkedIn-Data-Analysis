# %%
import os
import pandas as pd
import chardet

# %%
def detect_encoding(file_path):
    """
    Detects the encoding of a file.

    Args:
        file_path (str): The path to the file.

    Returns:
        str: The encoding of the file.
    """
    with open(file_path, "rb") as f:
        result = chardet.detect(f.read())
    return result["encoding"]


def remove_invalid_codec_rows(directory, output_directory="cleaned_data"):
    """
    Removes rows with invalid codec from all CSV files in a directory, attempting multiple encodings.

    Args:
        directory (str): The path to the directory containing the CSV files.
        output_directory (str): The path to the directory where cleaned files will be saved. Defaults to 'cleaned_data'.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    encodings_to_try = [
        "utf-8",
        "latin1",
        "ISO-8859-1",
        "cp1252",
        "Windows-1252",  # Common for Western European languages
        "ASCII",  # Basic text encoding
        "UTF-16",  # Used in some cases for extended character sets
    ]

    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            df = None  # Initialize df outside the try block
            for encoding in encodings_to_try:
                try:
                    df = pd.read_csv(filepath, encoding=encoding)
                    print(f"Successfully read {filename} with encoding: {encoding}")
                    break  # If successful, break the inner loop and proceed
                except UnicodeDecodeError:
                    print(f"Failed to decode {filename} with {encoding}.")
                except Exception as e:
                    print(f"An unexpected error occurred: {e}")
                    break  # Break the inner loop on unexpected errors

            if df is not None:
                # Save the cleaned file to the output directory
                output_filepath = os.path.join(output_directory, filename)
                try:
                    df.to_csv(
                        output_filepath, index=False, encoding="utf-8"
                    )  # Always save as UTF-8
                    print(
                        f"Removed invalid codec rows from: {filename} and saved to {output_filepath}"
                    )
                except Exception as e:
                    print(f"Error saving {filename}: {e}")
            else:
                print(f"Could not decode {filename} with any of the tried encodings.")


remove_invalid_codec_rows("renamed_data")
# Out:
# Successfully read Aaditya Raj.csv with encoding: utf-8
# Removed invalid codec rows from: Aaditya Raj.csv and saved to cleaned_data\Aaditya Raj.csv
# Successfully read Abhishek Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Abhishek Singh.csv and saved to cleaned_data\Abhishek Singh.csv
# Successfully read Aditya Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Aditya Singh.csv and saved to cleaned_data\Aditya Singh.csv
# Successfully read Afzal Raza.csv with encoding: utf-8
# Removed invalid codec rows from: Afzal Raza.csv and saved to cleaned_data\Afzal Raza.csv
# Successfully read Ajay Jatav.csv with encoding: utf-8
# Removed invalid codec rows from: Ajay Jatav.csv and saved to cleaned_data\Ajay Jatav.csv
# Successfully read Ajit Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Ajit Yadav.csv and saved to cleaned_data\Ajit Yadav.csv
# Successfully read Akanksha Kushwaha.csv with encoding: utf-8
# Removed invalid codec rows from: Akanksha Kushwaha.csv and saved to cleaned_data\Akanksha Kushwaha.csv
# Successfully read Alok Raj.csv with encoding: utf-8
# Removed invalid codec rows from: Alok Raj.csv and saved to cleaned_data\Alok Raj.csv
# Successfully read Aman Adarsh.csv with encoding: utf-8
# Removed invalid codec rows from: Aman Adarsh.csv and saved to cleaned_data\Aman Adarsh.csv
# Successfully read Aman Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Aman Singh.csv and saved to cleaned_data\Aman Singh.csv
# Successfully read Aman Verma.csv with encoding: utf-8
# Removed invalid codec rows from: Aman Verma.csv and saved to cleaned_data\Aman Verma.csv
# Successfully read Amit Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Amit Kumar.csv and saved to cleaned_data\Amit Kumar.csv
# Failed to decode Anamika Kumari.csv with utf-8.
# Successfully read Anamika Kumari.csv with encoding: latin1
# Removed invalid codec rows from: Anamika Kumari.csv and saved to cleaned_data\Anamika Kumari.csv
# Successfully read Anand Pandey.csv with encoding: utf-8
# Removed invalid codec rows from: Anand Pandey.csv and saved to cleaned_data\Anand Pandey.csv
# Successfully read Anand Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Anand Singh.csv and saved to cleaned_data\Anand Singh.csv
# Successfully read Anoop Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Anoop Kumar.csv and saved to cleaned_data\Anoop Kumar.csv
# Successfully read Anshu Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Anshu Kumar.csv and saved to cleaned_data\Anshu Kumar.csv
# Failed to decode Anuradha Tiwari.csv with utf-8.
# Successfully read Anuradha Tiwari.csv with encoding: latin1
# Removed invalid codec rows from: Anuradha Tiwari.csv and saved to cleaned_data\Anuradha Tiwari.csv
# Successfully read Anushri Mishra.csv with encoding: utf-8
# Removed invalid codec rows from: Anushri Mishra.csv and saved to cleaned_data\Anushri Mishra.csv
# Successfully read Aradhya Patel.csv with encoding: utf-8
# Removed invalid codec rows from: Aradhya Patel.csv and saved to cleaned_data\Aradhya Patel.csv
# Successfully read Arjun Kadam.csv with encoding: utf-8
# Removed invalid codec rows from: Arjun Kadam.csv and saved to cleaned_data\Arjun Kadam.csv
# Successfully read Arpita Tripathi.csv with encoding: utf-8
# Removed invalid codec rows from: Arpita Tripathi.csv and saved to cleaned_data\Arpita Tripathi.csv
# Successfully read Arun Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Arun Singh.csv and saved to cleaned_data\Arun Singh.csv
# Successfully read Aryan Saini.csv with encoding: utf-8
# Removed invalid codec rows from: Aryan Saini.csv and saved to cleaned_data\Aryan Saini.csv
# Successfully read Ashwin Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Ashwin Yadav.csv and saved to cleaned_data\Ashwin Yadav.csv
# Successfully read Ayush Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Ayush Kumar.csv and saved to cleaned_data\Ayush Kumar.csv
# Successfully read Ayush Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Ayush Yadav.csv and saved to cleaned_data\Ayush Yadav.csv
# Successfully read Bhagwan Singh Rawat.csv with encoding: utf-8
# Removed invalid codec rows from: Bhagwan Singh Rawat.csv and saved to cleaned_data\Bhagwan Singh Rawat.csv
# Successfully read Bhagwati Chouhan.csv with encoding: utf-8
# Removed invalid codec rows from: Bhagwati Chouhan.csv and saved to cleaned_data\Bhagwati Chouhan.csv
# Successfully read Bhaskar Mahato.csv with encoding: utf-8
# Removed invalid codec rows from: Bhaskar Mahato.csv and saved to cleaned_data\Bhaskar Mahato.csv
# Successfully read Byagari Praveen Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Byagari Praveen Kumar.csv and saved to cleaned_data\Byagari Praveen Kumar.csv
# Successfully read Challa Trivedh Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Challa Trivedh Kumar.csv and saved to cleaned_data\Challa Trivedh Kumar.csv
# Failed to decode Chandan Giri.csv with utf-8.
# Successfully read Chandan Giri.csv with encoding: latin1
# Removed invalid codec rows from: Chandan Giri.csv and saved to cleaned_data\Chandan Giri.csv
# Successfully read Chiranjeet Biswas.csv with encoding: utf-8
# Removed invalid codec rows from: Chiranjeet Biswas.csv and saved to cleaned_data\Chiranjeet Biswas.csv
# Successfully read Debangsu Misra.csv with encoding: utf-8
# Removed invalid codec rows from: Debangsu Misra.csv and saved to cleaned_data\Debangsu Misra.csv
# Successfully read Dilip Suthar.csv with encoding: utf-8
# Removed invalid codec rows from: Dilip Suthar.csv and saved to cleaned_data\Dilip Suthar.csv
# Successfully read Disha Sahu.csv with encoding: utf-8
# Removed invalid codec rows from: Disha Sahu.csv and saved to cleaned_data\Disha Sahu.csv
# Successfully read Divyanshi Rathour.csv with encoding: utf-8
# Removed invalid codec rows from: Divyanshi Rathour.csv and saved to cleaned_data\Divyanshi Rathour.csv
# Successfully read Divyanshi Sahu.csv with encoding: utf-8
# Removed invalid codec rows from: Divyanshi Sahu.csv and saved to cleaned_data\Divyanshi Sahu.csv
# Successfully read Ekta Kumari.csv with encoding: utf-8
# Removed invalid codec rows from: Ekta Kumari.csv and saved to cleaned_data\Ekta Kumari.csv
# Successfully read Gaurav Khainwar.csv with encoding: utf-8
# Removed invalid codec rows from: Gaurav Khainwar.csv and saved to cleaned_data\Gaurav Khainwar.csv
# Successfully read Gaurav Rathore.csv with encoding: utf-8
# Removed invalid codec rows from: Gaurav Rathore.csv and saved to cleaned_data\Gaurav Rathore.csv
# Successfully read Gaurav Tiwari.csv with encoding: utf-8
# Removed invalid codec rows from: Gaurav Tiwari.csv and saved to cleaned_data\Gaurav Tiwari.csv
# Successfully read Harisingh Rajpoot.csv with encoding: utf-8
# Removed invalid codec rows from: Harisingh Rajpoot.csv and saved to cleaned_data\Harisingh Rajpoot.csv
# Successfully read Harshit Chaturvedi.csv with encoding: utf-8
# Removed invalid codec rows from: Harshit Chaturvedi.csv and saved to cleaned_data\Harshit Chaturvedi.csv
# Successfully read Himanshu Kanwar Chundawat.csv with encoding: utf-8
# Removed invalid codec rows from: Himanshu Kanwar Chundawat.csv and saved to cleaned_data\Himanshu Kanwar Chundawat.csv
# Successfully read Himanshu Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Himanshu Kumar.csv and saved to cleaned_data\Himanshu Kumar.csv
# Successfully read Himanshu Srivastav.csv with encoding: utf-8
# Removed invalid codec rows from: Himanshu Srivastav.csv and saved to cleaned_data\Himanshu Srivastav.csv
# Successfully read Hiranya Patil.csv with encoding: utf-8
# Removed invalid codec rows from: Hiranya Patil.csv and saved to cleaned_data\Hiranya Patil.csv
# Successfully read Ishant Bhoyar.csv with encoding: utf-8
# Removed invalid codec rows from: Ishant Bhoyar.csv and saved to cleaned_data\Ishant Bhoyar.csv
# Successfully read Jamal Akhtar.csv with encoding: utf-8
# Removed invalid codec rows from: Jamal Akhtar.csv and saved to cleaned_data\Jamal Akhtar.csv
# Successfully read Janu Chaudhary.csv with encoding: utf-8
# Removed invalid codec rows from: Janu Chaudhary.csv and saved to cleaned_data\Janu Chaudhary.csv
# Successfully read KARANPAL SINGH RANAWAT.csv with encoding: utf-8
# Removed invalid codec rows from: KARANPAL SINGH RANAWAT.csv and saved to cleaned_data\KARANPAL SINGH RANAWAT.csv
# Successfully read Khushi Narwariya.csv with encoding: utf-8
# Removed invalid codec rows from: Khushi Narwariya.csv and saved to cleaned_data\Khushi Narwariya.csv
# Successfully read Kuldeep Saraswat.csv with encoding: utf-8
# Removed invalid codec rows from: Kuldeep Saraswat.csv and saved to cleaned_data\Kuldeep Saraswat.csv
# Successfully read Lakhan Rathore.csv with encoding: utf-8
# Removed invalid codec rows from: Lakhan Rathore.csv and saved to cleaned_data\Lakhan Rathore.csv
# Successfully read Maneesh Sakhwar.csv with encoding: utf-8
# Removed invalid codec rows from: Maneesh Sakhwar.csv and saved to cleaned_data\Maneesh Sakhwar.csv
# Successfully read Manish Tiwari.csv with encoding: utf-8
# Removed invalid codec rows from: Manish Tiwari.csv and saved to cleaned_data\Manish Tiwari.csv
# Successfully read Manoj Dewda.csv with encoding: utf-8
# Removed invalid codec rows from: Manoj Dewda.csv and saved to cleaned_data\Manoj Dewda.csv
# Successfully read Manoj Kharkar.csv with encoding: utf-8
# Removed invalid codec rows from: Manoj Kharkar.csv and saved to cleaned_data\Manoj Kharkar.csv
# Successfully read Mausam Kumari.csv with encoding: utf-8
# Removed invalid codec rows from: Mausam Kumari.csv and saved to cleaned_data\Mausam Kumari.csv
# Successfully read Mayank Raj.csv with encoding: utf-8
# Removed invalid codec rows from: Mayank Raj.csv and saved to cleaned_data\Mayank Raj.csv
# Successfully read Mehtab Alam.csv with encoding: utf-8
# Removed invalid codec rows from: Mehtab Alam.csv and saved to cleaned_data\Mehtab Alam.csv
# Successfully read Mohd Monis.csv with encoding: utf-8
# Removed invalid codec rows from: Mohd Monis.csv and saved to cleaned_data\Mohd Monis.csv
# Successfully read Mohit Sharma.csv with encoding: utf-8
# Removed invalid codec rows from: Mohit Sharma.csv and saved to cleaned_data\Mohit Sharma.csv
# Successfully read Monu Rajpoot.csv with encoding: utf-8
# Removed invalid codec rows from: Monu Rajpoot.csv and saved to cleaned_data\Monu Rajpoot.csv
# Successfully read N. Arun Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: N. Arun Kumar.csv and saved to cleaned_data\N. Arun Kumar.csv
# Successfully read Naman Damami.csv with encoding: utf-8
# Removed invalid codec rows from: Naman Damami.csv and saved to cleaned_data\Naman Damami.csv
# Successfully read Neeraj Parmar.csv with encoding: utf-8
# Removed invalid codec rows from: Neeraj Parmar.csv and saved to cleaned_data\Neeraj Parmar.csv
# Successfully read Nidhi Kumari.csv with encoding: utf-8
# Removed invalid codec rows from: Nidhi Kumari.csv and saved to cleaned_data\Nidhi Kumari.csv
# Successfully read Nikhil Chaurasiya.csv with encoding: utf-8
# Removed invalid codec rows from: Nikhil Chaurasiya.csv and saved to cleaned_data\Nikhil Chaurasiya.csv
# Successfully read Nirmal Mewada.csv with encoding: utf-8
# Removed invalid codec rows from: Nirmal Mewada.csv and saved to cleaned_data\Nirmal Mewada.csv
# Successfully read Ompal Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Ompal Yadav.csv and saved to cleaned_data\Ompal Yadav.csv
# Successfully read Pawan Kushwah.csv with encoding: utf-8
# Removed invalid codec rows from: Pawan Kushwah.csv and saved to cleaned_data\Pawan Kushwah.csv
# Successfully read Pinky Rana.csv with encoding: utf-8
# Removed invalid codec rows from: Pinky Rana.csv and saved to cleaned_data\Pinky Rana.csv
# Successfully read Pooran Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Pooran Singh.csv and saved to cleaned_data\Pooran Singh.csv
# Successfully read Prabhat Patidar.csv with encoding: utf-8
# Removed invalid codec rows from: Prabhat Patidar.csv and saved to cleaned_data\Prabhat Patidar.csv
# Successfully read Prachi Dhakad.csv with encoding: utf-8
# Removed invalid codec rows from: Prachi Dhakad.csv and saved to cleaned_data\Prachi Dhakad.csv
# Successfully read Pragati Chauhan.csv with encoding: utf-8
# Removed invalid codec rows from: Pragati Chauhan.csv and saved to cleaned_data\Pragati Chauhan.csv
# Successfully read Pranjal Dubey.csv with encoding: utf-8
# Removed invalid codec rows from: Pranjal Dubey.csv and saved to cleaned_data\Pranjal Dubey.csv
# Successfully read Prem kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Prem kumar.csv and saved to cleaned_data\Prem kumar.csv
# Failed to decode Prerana Rajnag.csv with utf-8.
# Successfully read Prerana Rajnag.csv with encoding: latin1
# Removed invalid codec rows from: Prerana Rajnag.csv and saved to cleaned_data\Prerana Rajnag.csv
# Successfully read Priya Saini.csv with encoding: utf-8
# Removed invalid codec rows from: Priya Saini.csv and saved to cleaned_data\Priya Saini.csv
# Successfully read Priyadarshi Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Priyadarshi Kumar.csv and saved to cleaned_data\Priyadarshi Kumar.csv
# Successfully read Pushpraj Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Pushpraj Singh.csv and saved to cleaned_data\Pushpraj Singh.csv
# Successfully read Rahul Kumar Verma.csv with encoding: utf-8
# Removed invalid codec rows from: Rahul Kumar Verma.csv and saved to cleaned_data\Rahul Kumar Verma.csv
# Successfully read Rahul Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Rahul Kumar.csv and saved to cleaned_data\Rahul Kumar.csv
# Successfully read Rajiv Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Rajiv Kumar.csv and saved to cleaned_data\Rajiv Kumar.csv
# Successfully read Ramraj Nagar.csv with encoding: utf-8
# Removed invalid codec rows from: Ramraj Nagar.csv and saved to cleaned_data\Ramraj Nagar.csv
# Successfully read Rani Kumari.csv with encoding: utf-8
# Removed invalid codec rows from: Rani Kumari.csv and saved to cleaned_data\Rani Kumari.csv
# Successfully read Ranjeet Kumar Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Ranjeet Kumar Yadav.csv and saved to cleaned_data\Ranjeet Kumar Yadav.csv
# Successfully read Ravi Mourya.csv with encoding: utf-8
# Removed invalid codec rows from: Ravi Mourya.csv and saved to cleaned_data\Ravi Mourya.csv
# Successfully read Ravi Rajput.csv with encoding: utf-8
# Removed invalid codec rows from: Ravi Rajput.csv and saved to cleaned_data\Ravi Rajput.csv
# Successfully read Ritik Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Ritik Singh.csv and saved to cleaned_data\Ritik Singh.csv
# Successfully read Rohit Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Rohit Kumar.csv and saved to cleaned_data\Rohit Kumar.csv
# Successfully read Rohit Malviya.csv with encoding: utf-8
# Removed invalid codec rows from: Rohit Malviya.csv and saved to cleaned_data\Rohit Malviya.csv
# Successfully read Sajan Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Sajan Kumar.csv and saved to cleaned_data\Sajan Kumar.csv
# Successfully read Samina Sultana.csv with encoding: utf-8
# Removed invalid codec rows from: Samina Sultana.csv and saved to cleaned_data\Samina Sultana.csv
# Successfully read Sandeep Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Sandeep Kumar.csv and saved to cleaned_data\Sandeep Kumar.csv
# Successfully read Sandhya Kaushal.csv with encoding: utf-8
# Removed invalid codec rows from: Sandhya Kaushal.csv and saved to cleaned_data\Sandhya Kaushal.csv
# Successfully read Sandhya Parmar.csv with encoding: utf-8
# Removed invalid codec rows from: Sandhya Parmar.csv and saved to cleaned_data\Sandhya Parmar.csv
# Failed to decode Sarthaksuman Mishra.csv with utf-8.
# Successfully read Sarthaksuman Mishra.csv with encoding: latin1
# Removed invalid codec rows from: Sarthaksuman Mishra.csv and saved to cleaned_data\Sarthaksuman Mishra.csv
# Successfully read Satish Mahto.csv with encoding: utf-8
# Removed invalid codec rows from: Satish Mahto.csv and saved to cleaned_data\Satish Mahto.csv
# Successfully read Sauhard Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Sauhard Kumar.csv and saved to cleaned_data\Sauhard Kumar.csv
# Successfully read Saurabh Bisht.csv with encoding: utf-8
# Removed invalid codec rows from: Saurabh Bisht.csv and saved to cleaned_data\Saurabh Bisht.csv
# Successfully read Shahid Ansari.csv with encoding: utf-8
# Removed invalid codec rows from: Shahid Ansari.csv and saved to cleaned_data\Shahid Ansari.csv
# Successfully read Shilpi Shaw.csv with encoding: utf-8
# Removed invalid codec rows from: Shilpi Shaw.csv and saved to cleaned_data\Shilpi Shaw.csv
# Successfully read Shivam Shukla.csv with encoding: utf-8
# Removed invalid codec rows from: Shivam Shukla.csv and saved to cleaned_data\Shivam Shukla.csv
# Successfully read Shivang Dubey.csv with encoding: utf-8
# Removed invalid codec rows from: Shivang Dubey.csv and saved to cleaned_data\Shivang Dubey.csv
# Successfully read Shlok Gupta.csv with encoding: utf-8
# Removed invalid codec rows from: Shlok Gupta.csv and saved to cleaned_data\Shlok Gupta.csv
# Successfully read Shubham Kang.csv with encoding: utf-8
# Removed invalid codec rows from: Shubham Kang.csv and saved to cleaned_data\Shubham Kang.csv
# Successfully read Shubham Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Shubham Kumar.csv and saved to cleaned_data\Shubham Kumar.csv
# Successfully read Sneha Shaw.csv with encoding: utf-8
# Removed invalid codec rows from: Sneha Shaw.csv and saved to cleaned_data\Sneha Shaw.csv
# Successfully read Sunny Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Sunny Kumar.csv and saved to cleaned_data\Sunny Kumar.csv
# Successfully read Suyash Yadav.csv with encoding: utf-8
# Removed invalid codec rows from: Suyash Yadav.csv and saved to cleaned_data\Suyash Yadav.csv
# Successfully read Swati Kumari.csv with encoding: utf-8
# Removed invalid codec rows from: Swati Kumari.csv and saved to cleaned_data\Swati Kumari.csv
# Successfully read Ujjval Baijal.csv with encoding: utf-8
# Removed invalid codec rows from: Ujjval Baijal.csv and saved to cleaned_data\Ujjval Baijal.csv
# Successfully read Uppara Sai Maithreyi.csv with encoding: utf-8
# Removed invalid codec rows from: Uppara Sai Maithreyi.csv and saved to cleaned_data\Uppara Sai Maithreyi.csv
# Successfully read Vinay Gupta.csv with encoding: utf-8
# Removed invalid codec rows from: Vinay Gupta.csv and saved to cleaned_data\Vinay Gupta.csv
# Successfully read Vinay Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Vinay Kumar.csv and saved to cleaned_data\Vinay Kumar.csv
# Successfully read Vishal Bhardwaj.csv with encoding: utf-8
# Removed invalid codec rows from: Vishal Bhardwaj.csv and saved to cleaned_data\Vishal Bhardwaj.csv
# Successfully read Vishal Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Vishal Kumar.csv and saved to cleaned_data\Vishal Kumar.csv
# Successfully read Vivek Kumar.csv with encoding: utf-8
# Removed invalid codec rows from: Vivek Kumar.csv and saved to cleaned_data\Vivek Kumar.csv
# Successfully read Vivek Singh.csv with encoding: utf-8
# Removed invalid codec rows from: Vivek Singh.csv and saved to cleaned_data\Vivek Singh.csv
# Successfully read Yuvraj Chirag.csv with encoding: utf-8
# Removed invalid codec rows from: Yuvraj Chirag.csv and saved to cleaned_data\Yuvraj Chirag.csv
# Successfully read Yuvraj Singh Bhati.csv with encoding: utf-8
# Removed invalid codec rows from: Yuvraj Singh Bhati.csv and saved to cleaned_data\Yuvraj Singh Bhati.csv

# %%
def remove_blank_rows(directory):
    """
    Removes blank rows from all CSV files in a directory, modifying the files in place.

    Args:
        directory (str): The path to the directory containing the CSV files.
    """
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            try:
                df = pd.read_csv(filepath)
                df.dropna(
                    how="all", inplace=True
                )  # Remove rows where all values are NaN

                # Save the cleaned file, overwriting the original
                df.to_csv(filepath, index=False)
                print(f"Removed blank rows from: {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")


# Use the cleaned_data directory
remove_blank_rows("cleaned_data")
# Out:
# Removed blank rows from: Aaditya Raj.csv
# Removed blank rows from: Abhishek Singh.csv
# Removed blank rows from: Aditya Singh.csv
# Removed blank rows from: Afzal Raza.csv
# Removed blank rows from: Ajay Jatav.csv
# Removed blank rows from: Ajit Yadav.csv
# Removed blank rows from: Akanksha Kushwaha.csv
# Removed blank rows from: Alok Raj.csv
# Removed blank rows from: Aman Adarsh.csv
# Removed blank rows from: Aman Singh.csv
# Removed blank rows from: Aman Verma.csv
# Removed blank rows from: Amit Kumar.csv
# Removed blank rows from: Anamika Kumari.csv
# Removed blank rows from: Anand Pandey.csv
# Removed blank rows from: Anand Singh.csv
# Removed blank rows from: Anoop Kumar.csv
# Removed blank rows from: Anshu Kumar.csv
# Removed blank rows from: Anuradha Tiwari.csv
# Removed blank rows from: Anushri Mishra.csv
# Removed blank rows from: Aradhya Patel.csv
# Removed blank rows from: Arjun Kadam.csv
# Removed blank rows from: Arpita Tripathi.csv
# Removed blank rows from: Arun Singh.csv
# Removed blank rows from: Aryan Saini.csv
# Removed blank rows from: Ashwin Yadav.csv
# Removed blank rows from: Ayush Kumar.csv
# Removed blank rows from: Ayush Yadav.csv
# Removed blank rows from: Bhagwan Singh Rawat.csv
# Removed blank rows from: Bhagwati Chouhan.csv
# Removed blank rows from: Bhaskar Mahato.csv
# Removed blank rows from: Byagari Praveen Kumar.csv
# Removed blank rows from: Challa Trivedh Kumar.csv
# Removed blank rows from: Chandan Giri.csv
# Removed blank rows from: Chiranjeet Biswas.csv
# Removed blank rows from: Debangsu Misra.csv
# Removed blank rows from: Dilip Suthar.csv
# Removed blank rows from: Disha Sahu.csv
# Removed blank rows from: Divyanshi Rathour.csv
# Removed blank rows from: Divyanshi Sahu.csv
# Removed blank rows from: Ekta Kumari.csv
# Removed blank rows from: Gaurav Khainwar.csv
# Removed blank rows from: Gaurav Rathore.csv
# Removed blank rows from: Gaurav Tiwari.csv
# Removed blank rows from: Harisingh Rajpoot.csv
# Removed blank rows from: Harshit Chaturvedi.csv
# Removed blank rows from: Himanshu Kanwar Chundawat.csv
# Removed blank rows from: Himanshu Kumar.csv
# Removed blank rows from: Himanshu Srivastav.csv
# Removed blank rows from: Hiranya Patil.csv
# Removed blank rows from: Ishant Bhoyar.csv
# Removed blank rows from: Jamal Akhtar.csv
# Removed blank rows from: Janu Chaudhary.csv
# Removed blank rows from: KARANPAL SINGH RANAWAT.csv
# Removed blank rows from: Khushi Narwariya.csv
# Removed blank rows from: Kuldeep Saraswat.csv
# Removed blank rows from: Lakhan Rathore.csv
# Removed blank rows from: Maneesh Sakhwar.csv
# Removed blank rows from: Manish Tiwari.csv
# Removed blank rows from: Manoj Dewda.csv
# Removed blank rows from: Manoj Kharkar.csv
# Removed blank rows from: Mausam Kumari.csv
# Removed blank rows from: Mayank Raj.csv
# Removed blank rows from: Mehtab Alam.csv
# Removed blank rows from: Mohd Monis.csv
# Removed blank rows from: Mohit Sharma.csv
# Removed blank rows from: Monu Rajpoot.csv
# Removed blank rows from: N. Arun Kumar.csv
# Removed blank rows from: Naman Damami.csv
# Removed blank rows from: Neeraj Parmar.csv
# Removed blank rows from: Nidhi Kumari.csv
# Removed blank rows from: Nikhil Chaurasiya.csv
# Removed blank rows from: Nirmal Mewada.csv
# Removed blank rows from: Ompal Yadav.csv
# Removed blank rows from: Pawan Kushwah.csv
# Removed blank rows from: Pinky Rana.csv
# Removed blank rows from: Pooran Singh.csv
# Removed blank rows from: Prabhat Patidar.csv
# Removed blank rows from: Prachi Dhakad.csv
# Removed blank rows from: Pragati Chauhan.csv
# Removed blank rows from: Pranjal Dubey.csv
# Removed blank rows from: Prem kumar.csv
# Removed blank rows from: Prerana Rajnag.csv
# Removed blank rows from: Priya Saini.csv
# Removed blank rows from: Priyadarshi Kumar.csv
# Removed blank rows from: Pushpraj Singh.csv
# Removed blank rows from: Rahul Kumar Verma.csv
# Removed blank rows from: Rahul Kumar.csv
# Removed blank rows from: Rajiv Kumar.csv
# Removed blank rows from: Ramraj Nagar.csv
# Removed blank rows from: Rani Kumari.csv
# Removed blank rows from: Ranjeet Kumar Yadav.csv
# Removed blank rows from: Ravi Mourya.csv
# Removed blank rows from: Ravi Rajput.csv
# Removed blank rows from: Ritik Singh.csv
# Removed blank rows from: Rohit Kumar.csv
# Removed blank rows from: Rohit Malviya.csv
# Removed blank rows from: Sajan Kumar.csv
# Removed blank rows from: Samina Sultana.csv
# Removed blank rows from: Sandeep Kumar.csv
# Removed blank rows from: Sandhya Kaushal.csv
# Removed blank rows from: Sandhya Parmar.csv
# Removed blank rows from: Sarthaksuman Mishra.csv
# Removed blank rows from: Satish Mahto.csv
# Removed blank rows from: Sauhard Kumar.csv
# Removed blank rows from: Saurabh Bisht.csv
# Removed blank rows from: Shahid Ansari.csv
# Removed blank rows from: Shilpi Shaw.csv
# Removed blank rows from: Shivam Shukla.csv
# Removed blank rows from: Shivang Dubey.csv
# Removed blank rows from: Shlok Gupta.csv
# Removed blank rows from: Shubham Kang.csv
# Removed blank rows from: Shubham Kumar.csv
# Removed blank rows from: Sneha Shaw.csv
# Removed blank rows from: Sunny Kumar.csv
# Removed blank rows from: Suyash Yadav.csv
# Removed blank rows from: Swati Kumari.csv
# Removed blank rows from: Ujjval Baijal.csv
# Removed blank rows from: Uppara Sai Maithreyi.csv
# Removed blank rows from: Vinay Gupta.csv
# Removed blank rows from: Vinay Kumar.csv
# Removed blank rows from: Vishal Bhardwaj.csv
# Removed blank rows from: Vishal Kumar.csv
# Removed blank rows from: Vivek Kumar.csv
# Removed blank rows from: Vivek Singh.csv
# Removed blank rows from: Yuvraj Chirag.csv
# Removed blank rows from: Yuvraj Singh Bhati.csv

# %%
def remove_rows_before_header(directory, header_name="First Name"):
    """
    Removes all rows before the row containing the specified header in each CSV file in a directory.

    Args:
        directory (str): The path to the directory containing the CSV files.
        header_name (str): The name of the column to search for in the header row.  Defaults to 'First Name'.
    """
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            try:
                df = pd.read_csv(
                    filepath, header=None
                )  # Read without a header initially

                # Find the row containing the header
                header_row_index = None
                for i, row in df.iterrows():
                    if header_name in row.values:
                        header_row_index = i
                        break

                if header_row_index is not None:
                    # Set the header and remove rows before it
                    df.columns = df.iloc[header_row_index]
                    df = df[header_row_index + 1 :]
                    df.columns.name = None  # Remove the name of the columns
                    df.reset_index(drop=True, inplace=True)

                    df.to_csv(filepath, index=False)  # Save back to the same file
                    print(f"Removed rows before header from: {filename}")
                else:
                    print(f"Header '{header_name}' not found in: {filename}")

            except Exception as e:
                print(f"Error processing {filename}: {e}")


# Use the destination_directory variable, which is 'renamed_data'
remove_rows_before_header("cleaned_data")
# Out:
# Removed rows before header from: Aaditya Raj.csv
# Removed rows before header from: Abhishek Singh.csv
# Removed rows before header from: Aditya Singh.csv
# Removed rows before header from: Afzal Raza.csv
# Removed rows before header from: Ajay Jatav.csv
# Removed rows before header from: Ajit Yadav.csv
# Removed rows before header from: Akanksha Kushwaha.csv
# Removed rows before header from: Alok Raj.csv
# Removed rows before header from: Aman Adarsh.csv
# Removed rows before header from: Aman Singh.csv
# Removed rows before header from: Aman Verma.csv
# Removed rows before header from: Amit Kumar.csv
# Removed rows before header from: Anamika Kumari.csv
# Removed rows before header from: Anand Pandey.csv
# Removed rows before header from: Anand Singh.csv
# Removed rows before header from: Anoop Kumar.csv
# Removed rows before header from: Anshu Kumar.csv
# Removed rows before header from: Anuradha Tiwari.csv
# Removed rows before header from: Anushri Mishra.csv
# Removed rows before header from: Aradhya Patel.csv
# Removed rows before header from: Arjun Kadam.csv
# Removed rows before header from: Arpita Tripathi.csv
# Removed rows before header from: Arun Singh.csv
# Removed rows before header from: Aryan Saini.csv
# Removed rows before header from: Ashwin Yadav.csv
# Removed rows before header from: Ayush Kumar.csv
# Removed rows before header from: Ayush Yadav.csv
# Removed rows before header from: Bhagwan Singh Rawat.csv
# Removed rows before header from: Bhagwati Chouhan.csv
# Removed rows before header from: Bhaskar Mahato.csv
# Removed rows before header from: Byagari Praveen Kumar.csv
# Removed rows before header from: Challa Trivedh Kumar.csv
# Removed rows before header from: Chandan Giri.csv
# Removed rows before header from: Chiranjeet Biswas.csv
# Removed rows before header from: Debangsu Misra.csv
# Removed rows before header from: Dilip Suthar.csv
# Removed rows before header from: Disha Sahu.csv
# Removed rows before header from: Divyanshi Rathour.csv
# Removed rows before header from: Divyanshi Sahu.csv
# Removed rows before header from: Ekta Kumari.csv
# Removed rows before header from: Gaurav Khainwar.csv
# Removed rows before header from: Gaurav Rathore.csv
# Removed rows before header from: Gaurav Tiwari.csv
# Removed rows before header from: Harisingh Rajpoot.csv
# Removed rows before header from: Harshit Chaturvedi.csv
# Removed rows before header from: Himanshu Kanwar Chundawat.csv
# Removed rows before header from: Himanshu Kumar.csv
# Removed rows before header from: Himanshu Srivastav.csv
# Removed rows before header from: Hiranya Patil.csv
# Removed rows before header from: Ishant Bhoyar.csv
# Removed rows before header from: Jamal Akhtar.csv
# Removed rows before header from: Janu Chaudhary.csv
# Removed rows before header from: KARANPAL SINGH RANAWAT.csv
# Removed rows before header from: Khushi Narwariya.csv
# Removed rows before header from: Kuldeep Saraswat.csv
# Removed rows before header from: Lakhan Rathore.csv
# Removed rows before header from: Maneesh Sakhwar.csv
# Removed rows before header from: Manish Tiwari.csv
# Removed rows before header from: Manoj Dewda.csv
# Removed rows before header from: Manoj Kharkar.csv
# Removed rows before header from: Mausam Kumari.csv
# Removed rows before header from: Mayank Raj.csv
# Removed rows before header from: Mehtab Alam.csv
# Removed rows before header from: Mohd Monis.csv
# Removed rows before header from: Mohit Sharma.csv
# Removed rows before header from: Monu Rajpoot.csv
# Removed rows before header from: N. Arun Kumar.csv
# Removed rows before header from: Naman Damami.csv
# Removed rows before header from: Neeraj Parmar.csv
# Removed rows before header from: Nidhi Kumari.csv
# Removed rows before header from: Nikhil Chaurasiya.csv
# Removed rows before header from: Nirmal Mewada.csv
# Removed rows before header from: Ompal Yadav.csv
# Removed rows before header from: Pawan Kushwah.csv
# Removed rows before header from: Pinky Rana.csv
# Removed rows before header from: Pooran Singh.csv
# Removed rows before header from: Prabhat Patidar.csv
# Removed rows before header from: Prachi Dhakad.csv
# Removed rows before header from: Pragati Chauhan.csv
# Removed rows before header from: Pranjal Dubey.csv
# Removed rows before header from: Prem kumar.csv
# Removed rows before header from: Prerana Rajnag.csv
# Removed rows before header from: Priya Saini.csv
# Removed rows before header from: Priyadarshi Kumar.csv
# Removed rows before header from: Pushpraj Singh.csv
# Removed rows before header from: Rahul Kumar Verma.csv
# Removed rows before header from: Rahul Kumar.csv
# Removed rows before header from: Rajiv Kumar.csv
# Removed rows before header from: Ramraj Nagar.csv
# Removed rows before header from: Rani Kumari.csv
# Removed rows before header from: Ranjeet Kumar Yadav.csv
# Removed rows before header from: Ravi Mourya.csv
# Removed rows before header from: Ravi Rajput.csv
# Removed rows before header from: Ritik Singh.csv
# Removed rows before header from: Rohit Kumar.csv
# Removed rows before header from: Rohit Malviya.csv
# Removed rows before header from: Sajan Kumar.csv
# Removed rows before header from: Samina Sultana.csv
# Removed rows before header from: Sandeep Kumar.csv
# Removed rows before header from: Sandhya Kaushal.csv
# Removed rows before header from: Sandhya Parmar.csv
# Removed rows before header from: Sarthaksuman Mishra.csv
# Removed rows before header from: Satish Mahto.csv
# Removed rows before header from: Sauhard Kumar.csv
# Removed rows before header from: Saurabh Bisht.csv
# Removed rows before header from: Shahid Ansari.csv
# Removed rows before header from: Shilpi Shaw.csv
# Removed rows before header from: Shivam Shukla.csv
# Removed rows before header from: Shivang Dubey.csv
# Removed rows before header from: Shlok Gupta.csv
# Removed rows before header from: Shubham Kang.csv
# Removed rows before header from: Shubham Kumar.csv
# Removed rows before header from: Sneha Shaw.csv
# Removed rows before header from: Sunny Kumar.csv
# Removed rows before header from: Suyash Yadav.csv
# Removed rows before header from: Swati Kumari.csv
# Removed rows before header from: Ujjval Baijal.csv
# Removed rows before header from: Uppara Sai Maithreyi.csv
# Removed rows before header from: Vinay Gupta.csv
# Removed rows before header from: Vinay Kumar.csv
# Removed rows before header from: Vishal Bhardwaj.csv
# Removed rows before header from: Vishal Kumar.csv
# Removed rows before header from: Vivek Kumar.csv
# Removed rows before header from: Vivek Singh.csv
# Removed rows before header from: Yuvraj Chirag.csv
# Removed rows before header from: Yuvraj Singh Bhati.csv

# %%
def remove_extra_columns(directory):
    """
    Removes all columns except 'First Name', 'Last Name', and 'Company' from all CSV files in a directory.

    Args:
        directory (str): The path to the directory containing the CSV files.
    """
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            try:
                df = pd.read_csv(filepath)
                # Select only the desired columns, handling potential missing columns
                columns_to_keep = ["First Name", "Last Name", "Company"]
                existing_columns = [col for col in columns_to_keep if col in df.columns]

                df = df[existing_columns]

                df.to_csv(filepath, index=False)  # Save back to the same file
                print(f"Removed extra columns from: {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")


# Use the destination_directory variable, which is 'renamed_data'
remove_extra_columns("cleaned_data")
# Out:
# Removed extra columns from: Aaditya Raj.csv
# Removed extra columns from: Abhishek Singh.csv
# Removed extra columns from: Aditya Singh.csv
# Removed extra columns from: Afzal Raza.csv
# Removed extra columns from: Ajay Jatav.csv
# Removed extra columns from: Ajit Yadav.csv
# Removed extra columns from: Akanksha Kushwaha.csv
# Removed extra columns from: Alok Raj.csv
# Removed extra columns from: Aman Adarsh.csv
# Removed extra columns from: Aman Singh.csv
# Removed extra columns from: Aman Verma.csv
# Removed extra columns from: Amit Kumar.csv
# Removed extra columns from: Anamika Kumari.csv
# Removed extra columns from: Anand Pandey.csv
# Removed extra columns from: Anand Singh.csv
# Removed extra columns from: Anoop Kumar.csv
# Removed extra columns from: Anshu Kumar.csv
# Removed extra columns from: Anuradha Tiwari.csv
# Removed extra columns from: Anushri Mishra.csv
# Removed extra columns from: Aradhya Patel.csv
# Removed extra columns from: Arjun Kadam.csv
# Removed extra columns from: Arpita Tripathi.csv
# Removed extra columns from: Arun Singh.csv
# Removed extra columns from: Aryan Saini.csv
# Removed extra columns from: Ashwin Yadav.csv
# Removed extra columns from: Ayush Kumar.csv
# Removed extra columns from: Ayush Yadav.csv
# Removed extra columns from: Bhagwan Singh Rawat.csv
# Removed extra columns from: Bhagwati Chouhan.csv
# Removed extra columns from: Bhaskar Mahato.csv
# Removed extra columns from: Byagari Praveen Kumar.csv
# Removed extra columns from: Challa Trivedh Kumar.csv
# Removed extra columns from: Chandan Giri.csv
# Removed extra columns from: Chiranjeet Biswas.csv
# Removed extra columns from: Debangsu Misra.csv
# Removed extra columns from: Dilip Suthar.csv
# Removed extra columns from: Disha Sahu.csv
# Removed extra columns from: Divyanshi Rathour.csv
# Removed extra columns from: Divyanshi Sahu.csv
# Removed extra columns from: Ekta Kumari.csv
# Removed extra columns from: Gaurav Khainwar.csv
# Removed extra columns from: Gaurav Rathore.csv
# Removed extra columns from: Gaurav Tiwari.csv
# Removed extra columns from: Harisingh Rajpoot.csv
# Removed extra columns from: Harshit Chaturvedi.csv
# Removed extra columns from: Himanshu Kanwar Chundawat.csv
# Removed extra columns from: Himanshu Kumar.csv
# Removed extra columns from: Himanshu Srivastav.csv
# Removed extra columns from: Hiranya Patil.csv
# Removed extra columns from: Ishant Bhoyar.csv
# Removed extra columns from: Jamal Akhtar.csv
# Removed extra columns from: Janu Chaudhary.csv
# Removed extra columns from: KARANPAL SINGH RANAWAT.csv
# Removed extra columns from: Khushi Narwariya.csv
# Removed extra columns from: Kuldeep Saraswat.csv
# Removed extra columns from: Lakhan Rathore.csv
# Removed extra columns from: Maneesh Sakhwar.csv
# Removed extra columns from: Manish Tiwari.csv
# Removed extra columns from: Manoj Dewda.csv
# Removed extra columns from: Manoj Kharkar.csv
# Removed extra columns from: Mausam Kumari.csv
# Removed extra columns from: Mayank Raj.csv
# Removed extra columns from: Mehtab Alam.csv
# Removed extra columns from: Mohd Monis.csv
# Removed extra columns from: Mohit Sharma.csv
# Removed extra columns from: Monu Rajpoot.csv
# Removed extra columns from: N. Arun Kumar.csv
# Removed extra columns from: Naman Damami.csv
# Removed extra columns from: Neeraj Parmar.csv
# Removed extra columns from: Nidhi Kumari.csv
# Removed extra columns from: Nikhil Chaurasiya.csv
# Removed extra columns from: Nirmal Mewada.csv
# Removed extra columns from: Ompal Yadav.csv
# Removed extra columns from: Pawan Kushwah.csv
# Removed extra columns from: Pinky Rana.csv
# Removed extra columns from: Pooran Singh.csv
# Removed extra columns from: Prabhat Patidar.csv
# Removed extra columns from: Prachi Dhakad.csv
# Removed extra columns from: Pragati Chauhan.csv
# Removed extra columns from: Pranjal Dubey.csv
# Removed extra columns from: Prem kumar.csv
# Removed extra columns from: Prerana Rajnag.csv
# Removed extra columns from: Priya Saini.csv
# Removed extra columns from: Priyadarshi Kumar.csv
# Removed extra columns from: Pushpraj Singh.csv
# Removed extra columns from: Rahul Kumar Verma.csv
# Removed extra columns from: Rahul Kumar.csv
# Removed extra columns from: Rajiv Kumar.csv
# Removed extra columns from: Ramraj Nagar.csv
# Removed extra columns from: Rani Kumari.csv
# Removed extra columns from: Ranjeet Kumar Yadav.csv
# Removed extra columns from: Ravi Mourya.csv
# Removed extra columns from: Ravi Rajput.csv
# Removed extra columns from: Ritik Singh.csv
# Removed extra columns from: Rohit Kumar.csv
# Removed extra columns from: Rohit Malviya.csv
# Removed extra columns from: Sajan Kumar.csv
# Removed extra columns from: Samina Sultana.csv
# Removed extra columns from: Sandeep Kumar.csv
# Removed extra columns from: Sandhya Kaushal.csv
# Removed extra columns from: Sandhya Parmar.csv
# Removed extra columns from: Sarthaksuman Mishra.csv
# Removed extra columns from: Satish Mahto.csv
# Removed extra columns from: Sauhard Kumar.csv
# Removed extra columns from: Saurabh Bisht.csv
# Removed extra columns from: Shahid Ansari.csv
# Removed extra columns from: Shilpi Shaw.csv
# Removed extra columns from: Shivam Shukla.csv
# Removed extra columns from: Shivang Dubey.csv
# Removed extra columns from: Shlok Gupta.csv
# Removed extra columns from: Shubham Kang.csv
# Removed extra columns from: Shubham Kumar.csv
# Removed extra columns from: Sneha Shaw.csv
# Removed extra columns from: Sunny Kumar.csv
# Removed extra columns from: Suyash Yadav.csv
# Removed extra columns from: Swati Kumari.csv
# Removed extra columns from: Ujjval Baijal.csv
# Removed extra columns from: Uppara Sai Maithreyi.csv
# Removed extra columns from: Vinay Gupta.csv
# Removed extra columns from: Vinay Kumar.csv
# Removed extra columns from: Vishal Bhardwaj.csv
# Removed extra columns from: Vishal Kumar.csv
# Removed extra columns from: Vivek Kumar.csv
# Removed extra columns from: Vivek Singh.csv
# Removed extra columns from: Yuvraj Chirag.csv
# Removed extra columns from: Yuvraj Singh Bhati.csv

# %%
def sort_by_first_name(directory):
    """
    Sorts all CSV files in a directory by the 'First Name' column.

    Args:
        directory (str): The path to the directory containing the CSV files.
    """
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            filepath = os.path.join(directory, filename)
            try:
                df = pd.read_csv(filepath)
                # Check if 'First Name' column exists
                if "First Name" in df.columns:
                    df.sort_values(by="First Name", inplace=True)
                    df.to_csv(filepath, index=False)  # Save back to the same file
                    print(f"Sorted {filename} by 'First Name'")
                else:
                    print(f"'First Name' column not found in {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")


sort_by_first_name("cleaned_data")
# Out:
# Sorted Aaditya Raj.csv by 'First Name'
# Sorted Abhishek Singh.csv by 'First Name'
# Sorted Aditya Singh.csv by 'First Name'
# Sorted Afzal Raza.csv by 'First Name'
# Sorted Ajay Jatav.csv by 'First Name'
# Sorted Ajit Yadav.csv by 'First Name'
# Sorted Akanksha Kushwaha.csv by 'First Name'
# Sorted Alok Raj.csv by 'First Name'
# Sorted Aman Adarsh.csv by 'First Name'
# Sorted Aman Singh.csv by 'First Name'
# Sorted Aman Verma.csv by 'First Name'
# Sorted Amit Kumar.csv by 'First Name'
# Sorted Anamika Kumari.csv by 'First Name'
# Sorted Anand Pandey.csv by 'First Name'
# Sorted Anand Singh.csv by 'First Name'
# Sorted Anoop Kumar.csv by 'First Name'
# Sorted Anshu Kumar.csv by 'First Name'
# Sorted Anuradha Tiwari.csv by 'First Name'
# Sorted Anushri Mishra.csv by 'First Name'
# Sorted Aradhya Patel.csv by 'First Name'
# Sorted Arjun Kadam.csv by 'First Name'
# Sorted Arpita Tripathi.csv by 'First Name'
# Sorted Arun Singh.csv by 'First Name'
# Sorted Aryan Saini.csv by 'First Name'
# Sorted Ashwin Yadav.csv by 'First Name'
# Sorted Ayush Kumar.csv by 'First Name'
# Sorted Ayush Yadav.csv by 'First Name'
# Sorted Bhagwan Singh Rawat.csv by 'First Name'
# Sorted Bhagwati Chouhan.csv by 'First Name'
# Sorted Bhaskar Mahato.csv by 'First Name'
# Sorted Byagari Praveen Kumar.csv by 'First Name'
# Sorted Challa Trivedh Kumar.csv by 'First Name'
# Sorted Chandan Giri.csv by 'First Name'
# Sorted Chiranjeet Biswas.csv by 'First Name'
# Sorted Debangsu Misra.csv by 'First Name'
# Sorted Dilip Suthar.csv by 'First Name'
# Sorted Disha Sahu.csv by 'First Name'
# Sorted Divyanshi Rathour.csv by 'First Name'
# Sorted Divyanshi Sahu.csv by 'First Name'
# Sorted Ekta Kumari.csv by 'First Name'
# Sorted Gaurav Khainwar.csv by 'First Name'
# Sorted Gaurav Rathore.csv by 'First Name'
# Sorted Gaurav Tiwari.csv by 'First Name'
# Sorted Harisingh Rajpoot.csv by 'First Name'
# Sorted Harshit Chaturvedi.csv by 'First Name'
# Sorted Himanshu Kanwar Chundawat.csv by 'First Name'
# Sorted Himanshu Kumar.csv by 'First Name'
# Sorted Himanshu Srivastav.csv by 'First Name'
# Sorted Hiranya Patil.csv by 'First Name'
# Sorted Ishant Bhoyar.csv by 'First Name'
# Sorted Jamal Akhtar.csv by 'First Name'
# Sorted Janu Chaudhary.csv by 'First Name'
# Sorted KARANPAL SINGH RANAWAT.csv by 'First Name'
# Sorted Khushi Narwariya.csv by 'First Name'
# Sorted Kuldeep Saraswat.csv by 'First Name'
# Sorted Lakhan Rathore.csv by 'First Name'
# Sorted Maneesh Sakhwar.csv by 'First Name'
# Sorted Manish Tiwari.csv by 'First Name'
# Sorted Manoj Dewda.csv by 'First Name'
# Sorted Manoj Kharkar.csv by 'First Name'
# Sorted Mausam Kumari.csv by 'First Name'
# Sorted Mayank Raj.csv by 'First Name'
# Sorted Mehtab Alam.csv by 'First Name'
# Sorted Mohd Monis.csv by 'First Name'
# Sorted Mohit Sharma.csv by 'First Name'
# Sorted Monu Rajpoot.csv by 'First Name'
# Sorted N. Arun Kumar.csv by 'First Name'
# Sorted Naman Damami.csv by 'First Name'
# Sorted Neeraj Parmar.csv by 'First Name'
# Sorted Nidhi Kumari.csv by 'First Name'
# Sorted Nikhil Chaurasiya.csv by 'First Name'
# Sorted Nirmal Mewada.csv by 'First Name'
# Sorted Ompal Yadav.csv by 'First Name'
# Sorted Pawan Kushwah.csv by 'First Name'
# Sorted Pinky Rana.csv by 'First Name'
# Sorted Pooran Singh.csv by 'First Name'
# Sorted Prabhat Patidar.csv by 'First Name'
# Sorted Prachi Dhakad.csv by 'First Name'
# Sorted Pragati Chauhan.csv by 'First Name'
# Sorted Pranjal Dubey.csv by 'First Name'
# Sorted Prem kumar.csv by 'First Name'
# Sorted Prerana Rajnag.csv by 'First Name'
# Sorted Priya Saini.csv by 'First Name'
# Sorted Priyadarshi Kumar.csv by 'First Name'
# Sorted Pushpraj Singh.csv by 'First Name'
# Sorted Rahul Kumar Verma.csv by 'First Name'
# Sorted Rahul Kumar.csv by 'First Name'
# Sorted Rajiv Kumar.csv by 'First Name'
# Sorted Ramraj Nagar.csv by 'First Name'
# Sorted Rani Kumari.csv by 'First Name'
# Sorted Ranjeet Kumar Yadav.csv by 'First Name'
# Sorted Ravi Mourya.csv by 'First Name'
# Sorted Ravi Rajput.csv by 'First Name'
# Sorted Ritik Singh.csv by 'First Name'
# Sorted Rohit Kumar.csv by 'First Name'
# Sorted Rohit Malviya.csv by 'First Name'
# Sorted Sajan Kumar.csv by 'First Name'
# Sorted Samina Sultana.csv by 'First Name'
# Sorted Sandeep Kumar.csv by 'First Name'
# Sorted Sandhya Kaushal.csv by 'First Name'
# Sorted Sandhya Parmar.csv by 'First Name'
# Sorted Sarthaksuman Mishra.csv by 'First Name'
# Sorted Satish Mahto.csv by 'First Name'
# Sorted Sauhard Kumar.csv by 'First Name'
# Sorted Saurabh Bisht.csv by 'First Name'
# Sorted Shahid Ansari.csv by 'First Name'
# Sorted Shilpi Shaw.csv by 'First Name'
# Sorted Shivam Shukla.csv by 'First Name'
# Sorted Shivang Dubey.csv by 'First Name'
# Sorted Shlok Gupta.csv by 'First Name'
# Sorted Shubham Kang.csv by 'First Name'
# Sorted Shubham Kumar.csv by 'First Name'
# Sorted Sneha Shaw.csv by 'First Name'
# Sorted Sunny Kumar.csv by 'First Name'
# Sorted Suyash Yadav.csv by 'First Name'
# Sorted Swati Kumari.csv by 'First Name'
# Sorted Ujjval Baijal.csv by 'First Name'
# Sorted Uppara Sai Maithreyi.csv by 'First Name'
# Sorted Vinay Gupta.csv by 'First Name'
# Sorted Vinay Kumar.csv by 'First Name'
# Sorted Vishal Bhardwaj.csv by 'First Name'
# Sorted Vishal Kumar.csv by 'First Name'
# Sorted Vivek Kumar.csv by 'First Name'
# Sorted Vivek Singh.csv by 'First Name'
# Sorted Yuvraj Chirag.csv by 'First Name'
# Sorted Yuvraj Singh Bhati.csv by 'First Name'
